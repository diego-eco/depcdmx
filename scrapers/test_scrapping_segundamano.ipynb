# %%
"""
Module to scrape Segunda Mano DF appartments
and stores data in local storage as CSV.
"""
import requests
import pandas as pd
from pprint import pprint as pp
from bs4 import BeautifulSoup

# %%
# Vars
_base_url = "https://www.segundamano.mx/anuncios/ciudad-de-mexico/venta-inmuebles?page={}"
user_agent = "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.62 Safari/537.36"
ddir='data/'

# %%
def save(depts):
    """ Append page data

        Params:
        -----
        depts : list
            List of Departments
    """
    # Read Existant file to append
    _fname = ddir+"{}/segundamano.csv".format(dt.date.today().isoformat())
    try:
        df = pd.read_csv(_fname, delimiter='~')
    except:
        print('New file, creating folder..')
        try:
            os.mkdir(ddir+'{}'.format(dt.date.today().isoformat()))
            print('Created folder!')
        except:
            print('Folder exists already!')
        df = pd.DataFrame()
    # Append data
    depdf = pd.DataFrame(depts)
    print(depdf.head(1).to_dict())
    try:
        if df.empty:
            depdf.set_index(['name','location']).to_csv(_fname, sep='~')
            print('Correctly saved file: {}'.format(_fname))
        else:
            df = pd.concat([df, depdf])
            df.set_index(['name','location']).to_csv(_fname, sep='~')
            print('Correctly saved file: {}'.format(_fname))
    except Exception as e:
        print(e)
        print('Could not save file: {}'.format(_fname))

# %%
def scrape(content):
    """ Scrape all departments per page
    """
    data = []
    # Generate soup
    soup = BeautifulSoup(content, 'html.parser')
    with open(ddir+'segundamano.html', 'w') as _F:
        _F.write(soup.prettify())
    # Get Characteristics
    for d in soup.find_all(class_="ad"):
        print('----')
        try:
            print(d) 
        except Exception as e:
            print(e)
            continue
        break
    print('Found {} depts'.format(len(data)))
    return data

# %%
def paginate():
    """ Loop over pages to retrieve all info available

        Returns:
        -----
        pg_nums : int
            Number of pages scraped
    """
    pg_nums = 1
    while True:
        try:
            print(_base_url.format(pg_nums))
            r = requests.get(_base_url.format(pg_nums),
                headers={'user-agent': user_agent})
            if r.status_code != 200:
                raise Exception("Wrong Response")
            depts = scrape(r.content)
            if not depts:
                raise Exception("No more departments")
        except Exception as e:
            print(e)
            print('Finishing to retrieve info.')
            break
        # Store values
        #save(depts)
        pg_nums += 1
        break ###
    return pg_nums

# %%
pg_nums = 1
print(_base_url.format(pg_nums))
r = requests.get(_base_url.format(pg_nums), headers={'user-agent': user_agent})
r
# Out:
# https://www.segundamano.mx/anuncios/ciudad-de-mexico/venta-inmuebles?page=1
# <Response [200]>

# %%
data = []
content = r.content
# Generate soup
soup = BeautifulSoup(content, 'html.parser')
with open('..\data\segundamano.html', 'w') as _F:
    _F.write(soup.prettify())
# Get Characteristics
for d in soup.find_all(class_="card grid"):
    print('----')
    try:
        print(d) 
    except Exception as e:
        print(e)
        continue
    break
print('Found {} depts'.format(len(data)))
# Out:
# Found 0 depts

# %%
soup
# Out:
# <!DOCTYPE html>
# <html data-locale="es_MX" lang="es-MX"><head><meta charset="utf-8"/><meta content="width=device-width,initial-scale=1" name="viewport"/><meta content="app-id=934844916" name="apple-itunes-app"/><link href="/manifest-android.json" rel="manifest"/><link href="/anuncios/static/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://www.google-analytics.com/" rel="dns-prefetch"/><link crossorigin="" href="https://www.google-analytics.com/" rel="preconnect"/><link href="https://ib.adnxs.com" rel="dns-prefetch"/><link crossorigin="" href="https://ib.adnxs.com" rel="preconnect"/><meta content="index, follow" name="robots"/><title>Venta de Inmuebles en Ciudad de México | Segundamano.mx</title><meta content="53797 anuncios de venta inmuebles   🏘️ en venta de particulares y profesionales de segundamano y ocasión en Ciudad de México ✔️. Entra, revisa y encuentra 🔎 en Segundamano.mx." name="description"/><meta content="product.group" property="og:type"/><meta content="53797 anuncios de venta inmuebles   🏘️ en venta de particulares y profesionales de segundamano y ocasión en Ciudad de México ✔️. Entra, revisa y encuentra 🔎 en Segundamano.mx." property="og:description"/><meta content="Segundamano.mx" property="og:site_name"/><meta content="Venta de Inmuebles en Ciudad de México | Segundamano.mx" property="og:title"/><meta content="https://www.segundamano.mx/anuncios/ciudad-de-mexico/venta-inmuebles" property="og:url"/> <meta content="https://www.segundamano.mx/anuncios/static/img/og/img_share_re.png" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <link href="https://www.segundamano.mx/anuncios/ciudad-de-mexico/venta-inmuebles" rel="canonical"/><link href="android-app://mx.segundamano.android/segundamanomxapp/list/?category=1020&amp;region=11" rel="alternate"/><style>html{font-family:sans-serif;line-height:1.15;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}::-webkit-input-placeholder{color:inherit;opacity:.54}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}html{box-sizing:border-box}*,:after,:before{box-sizing:inherit}html{font-family:Helvetica Neue,Helvetica,Arial,sans-serif;font-size:62.5%}body{font-size:1.4rem}html{font-family:sans-serif;line-height:1.15;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}::-webkit-input-placeholder{color:inherit;opacity:.54}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}html{box-sizing:border-box}*,:after,:before{box-sizing:inherit}html{font-family:Helvetica Neue,Helvetica,Arial,sans-serif;font-size:62.5%}body{font-size:1.4rem}html{font-family:sans-serif;line-height:1.15;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}::-webkit-input-placeholder{color:inherit;opacity:.54}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}html{box-sizing:border-box}*,:after,:before{box-sizing:inherit}html{font-family:Helvetica Neue,Helvetica,Arial,sans-serif;font-size:62.5%}body{font-size:1.4rem}html{font-family:sans-serif;line-height:1.15;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}::-webkit-input-placeholder{color:inherit;opacity:.54}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}html{box-sizing:border-box}*,:after,:before{box-sizing:inherit}html{font-family:Helvetica Neue,Helvetica,Arial,sans-serif;font-size:62.5%}body{font-size:1.4rem}#app{min-height:50rem}#app,body{background:#f8f8f8;height:100%}html{font-family:sans-serif;line-height:1.15;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}::-webkit-input-placeholder{color:inherit;opacity:.54}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}html{box-sizing:border-box}*,:after,:before{box-sizing:inherit}html{font-family:Helvetica Neue,Helvetica,Arial,sans-serif;font-size:62.5%}body{font-size:1.4rem}html{font-family:sans-serif;line-height:1.15;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}::-webkit-input-placeholder{color:inherit;opacity:.54}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}html{box-sizing:border-box}*,:after,:before{box-sizing:inherit}html{font-family:Helvetica Neue,Helvetica,Arial,sans-serif;font-size:62.5%}body{font-size:1.4rem}html{font-family:sans-serif;line-height:1.15;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}::-webkit-input-placeholder{color:inherit;opacity:.54}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}html{box-sizing:border-box}*,:after,:before{box-sizing:inherit}html{font-family:Helvetica Neue,Helvetica,Arial,sans-serif;font-size:62.5%}body{font-size:1.4rem}</style><link href="/anuncios/static/css/chunk-vendors.725f5bf2.css" rel="stylesheet"/><link href="/anuncios/static/css/app.2d76f7bf.css" rel="stylesheet"/><style>#app:empty{margin:1rem;max-width:1024px;min-height:4rem;background-image:radial-gradient(circle 15px at 15px 15px,#d3d3d3 99%,transparent 0),linear-gradient(lightgray 24px,transparent 0),linear-gradient(lightgray 40px,transparent 0),linear-gradient(lightgray 24px,transparent 0),radial-gradient(circle 15px at 15px 15px,#d3d3d3 99%,transparent 0);background-repeat:no-repeat;background-size:30px 30px,136px 200px,108px 200px,25px 30px,30px 30px;background-position:0 6px,35px 8px,100% 0,calc(100% - 11rem) 8px,calc(100% - 20.5rem) 8px}@media only screen and (min-width:1080px){#app:empty{margin:auto;margin-top:2rem;background-position:0 6px,35px 8px,100% 0,calc(100% - 12rem) 8px,calc(100% - 21.5rem) 8px}}@media screen and (max-width:768px){#app:empty{background-size:3 ...
# var adsPerPage='28'
# var SMMX={config:{domain:"segundamano.mx",webapiUrl:"https://webapi.segundamano.mx/nga/api",env:"prod",facebookAppId:"305785156580787",googleClientId:"990131190689-d9a241im30u9jgp75s16ibg7952lntoc.apps.googleusercontent.com",}}
# var staticVersion=""
# var sentryURL="https://90754c5b99c54a2487d1332fc359278c@o524880.ingest.sentry.io/6008040"
# var sentrySampleRate=0.01
# var pageTitle="Venta de Inmuebles en Ciudad de México"
# var listingfilters={"category":"1020","category_lv0":"1000","category_lv1":"1020","lim":"28","region":"11",}
# var formbuilderfilters={"category":"1020","category_lv0":"1000","category_lv1":"1020","lim":"28","region":"11",}
# var filtersForm="{\"form\":{\"id\":\"filterlinks\",\"label\":\"Filtros\",\"type\":\"group\",\"actionlabel\":\"Buscar\",\"fields\":[{\"id\":\"q\",\"type\":\"text\",\"label\":\"¿Qué buscas?\",\"hint\":\"Indica que estás buscando\",\"display\":\"inline\",\"disabled\":true,\"hidden\":true,\"value\":\"\"},{\"id\":\"location_section\",\"type\":\"fieldset\",\"display\":\"inline\",\"fields\":[{\"id\":\"region\",\"type\":\"picker\",\"label\":\"Estado\",\"hint\":\"Todos los estados\",\"display\":\"autocomplete\",\"datalist\":[{\"value\":\"\",\"text\":\"Todas las regiones\",\"URL\":\"/anuncios/mexico/venta-inmuebles\"},{\"value\":\"3\",\"text\":\"Aguascalientes\",\"URL\":\"/anuncios/aguascalientes/venta-inmuebles\"},{\"value\":\"4\",\"text\":\"Baja California\",\"URL\":\"/anuncios/baja-california/venta-inmuebles\"},{\"value\":\"5\",\"text\":\"Baja California Sur\",\"URL\":\"/anuncios/baja-california-sur/venta-inmuebles\"},{\"value\":\"6\",\"text\":\"Campeche\",\"URL\":\"/anuncios/campeche/venta-inmuebles\"},{\"value\":\"9\",\"text\":\"Chiapas\",\"URL\":\"/anuncios/chiapas/venta-inmuebles\"},{\"value\":\"10\",\"text\":\"Chihuahua\",\"URL\":\"/anuncios/chihuahua/venta-inmuebles\"},{\"value\":\"11\",\"text\":\"Ciudad de México\",\"URL\":\"/anuncios/ciudad-de-mexico/venta-inmuebles\"},{\"value\":\"7\",\"text\":\"Coahuila\",\"URL\":\"/anuncios/coahuila/venta-inmuebles\"},{\"value\":\"8\",\"text\":\"Colima\",\"URL\":\"/anuncios/colima/venta-inmuebles\"},{\"value\":\"12\",\"text\":\"Durango\",\"URL\":\"/anuncios/durango/venta-inmuebles\"},{\"value\":\"17\",\"text\":\"Estado de México\",\"URL\":\"/anuncios/estado-de-mexico/venta-inmuebles\"},{\"value\":\"13\",\"text\":\"Guanajuato\",\"URL\":\"/anuncios/guanajuato/venta-inmuebles\"},{\"value\":\"14\",\"text\":\"Guerrero\",\"URL\":\"/anuncios/guerrero/venta-inmuebles\"},{\"value\":\"15\",\"text\":\"Hidalgo\",\"URL\":\"/anuncios/hidalgo/venta-inmuebles\"},{\"value\":\"16\",\"text\":\"Jalisco\",\"URL\":\"/anuncios/jalisco/venta-inmuebles\"},{\"value\":\"18\",\"text\":\"Michoacán\",\"URL\":\"/anuncios/michoacan/venta-inmuebles\"},{\"value\":\"19\",\"text\":\"Morelos\",\"URL\":\"/anuncios/morelos/venta-inmuebles\"},{\"value\":\"20\",\"text\":\"Nayarit\",\"URL\":\"/anuncios/nayarit/venta-inmuebles\"},{\"value\":\"21\",\"text\":\"Nuevo León\",\"URL\":\"/anuncios/nuevo-leon/venta-inmuebles\"},{\"value\":\"22\",\"text\":\"Oaxaca\",\"URL\":\"/anuncios/oaxaca/venta-inmuebles\"},{\"value\":\"23\",\"text\":\"Puebla\",\"URL\":\"/anuncios/puebla/venta-inmuebles\"},{\"value\":\"24\",\"text\":\"Querétaro\",\"URL\":\"/anuncios/queretaro/venta-inmuebles\"},{\"value\":\"25\",\"text\":\"Quintana Roo\",\"URL\":\"/anuncios/quintana-roo/venta-inmuebles\"},{\"value\":\"26\",\"text\":\"San Luis Potosí\",\"URL\":\"/anuncios/san-luis-potosi/venta-inmuebles\"},{\"value\":\"27\",\"text\":\"Sinaloa\",\"URL\":\"/anuncios/sinaloa/venta-inmuebles\"},{\"value\":\"28\",\"text\":\"Sonora\",\"URL\":\"/anuncios/sonora/venta-inmuebles\"},{\"value\":\"29\",\"text\":\"Tabasco\",\"URL\":\"/anuncios/tabasco/venta-inmuebles\"},{\"value\":\"30\",\"text\":\"Tamaulipas\",\"URL\":\"/anuncios/tamaulipas/venta-inmuebles\"},{\"value\":\"31\",\"text\":\"Tlaxcala\",\"URL\":\"/anuncios/tlaxcala/venta-inmuebles\"},{\"value\":\"32\",\"text\":\"Veracruz\",\"URL\":\"/anuncios/veracruz/venta-inmuebles\"},{\"value\":\"33\",\"text\":\"Yucatán\",\"URL\":\"/anuncios/yucatan/venta-inmuebles\"},{\"value\":\"34\",\"text\":\"Zacatecas\",\"URL\":\"/anuncios/zacatecas/venta-inmuebles\"}],\"value\":\"11\",\"topItems\":[{\"value\":\"11\",\"text\":\"Ciudad de México\",\"URL\":\"/anuncios/ciudad-de-mexico/venta-inmuebles\"},{\"value\":\"16\",\"text\":\"Jalisco\",\"URL\":\"/anuncios/jalisco/venta-inmuebles\"},{\"value\":\"17\",\"text\":\"Estado de México\",\"URL\":\"/anuncios/estado-de-mexico/venta-inmuebles\"},{\"value\":\"21\",\"text\":\"Nuevo León\",\"URL\":\"/anuncios/nuevo-leon/venta-inmuebles\"},{\"value\":\"23\",\"text\":\"Puebla\",\"URL\":\"/anuncios/puebla/vent ...
# var initialAds="{\"list_ads\":[{\"ad\":{\"list_id\":\"/public/ads/939675809\",\"list_price\":{\"currency\":\"MXN\",\"label\":\"$ 6,000,000\",\"price_value\":6000000},\"prices\":[{\"currency\":\"MXN\",\"label\":\"$ 6,000,000\",\"price_value\":6000000}],\"share_link\":\"https://www.segundamano.mx/anuncios/ciudad-de-mexico/azcapotzalco/venta-inmuebles/estrene-magnifico-ph-en-residencial-jardines-azca-939675809\",\"subject\":\"Estrene magnifico PH en Residencial Jardines, Azca\",\"thumbnail\":{\"path\":\"16/1671017215.jpg\",\"base_url\":\"http://img.segundamano.mx\"},\"images\":[{\"path\":\"16/1671017215.jpg\",\"base_url\":\"http://img.segundamano.mx\"},{\"path\":\"16/1662493896.jpg\",\"base_url\":\"http://img.segundamano.mx\"},{\"path\":\"16/1653970577.jpg\",\"base_url\":\"http://img.segundamano.mx\"},{\"path\":\"16/1636923939.jpg\",\"base_url\":\"http://img.segundamano.mx\"},{\"path\":\"16/1628400620.jpg\",\"base_url\":\"http://img.segundamano.mx\"},{\"path\":\"16/1611353982.jpg\",\"base_url\":\"http://img.segundamano.mx\"},{\"path\":\"16/1619877301.jpg\",\"base_url\":\"http://img.segundamano.mx\"},{\"path\":\"16/1602830663.jpg\",\"base_url\":\"http://img.segundamano.mx\"},{\"path\":\"16/1694307344.jpg\",\"base_url\":\"http://img.segundamano.mx\"},{\"path\":\"16/1685784025.jpg\",\"base_url\":\"http://img.segundamano.mx\"},{\"path\":\"16/1677260706.jpg\",\"base_url\":\"http://img.segundamano.mx\"},{\"path\":\"16/1651690749.jpg\",\"base_url\":\"http://img.segundamano.mx\"},{\"path\":\"16/1660214068.jpg\",\"base_url\":\"http://img.segundamano.mx\"},{\"path\":\"16/1668737387.jpg\",\"base_url\":\"http://img.segundamano.mx\"}],\"user\":{\"account\":{\"name\":\"ASPRO BIENES RAICES\",\"since\":\"2019-12-04 10:49:04.132575\",\"user_uuid\":\"db0e4e42-b350-4778-9a83-8ea72793b126\"}},\"locations\":[{\"code\":\"11\",\"key\":\"region\",\"label\":\"Ciudad de México\",\"locations\":[{\"code\":\"291\",\"key\":\"municipality\",\"label\":\"Azcapotzalco\",\"locations\":[{\"code\":\"33648\",\"key\":\"area\",\"label\":\"San Miguel Amantla\"}]}]}],\"shop\":{\"id\":7168},\"body\":\"En Renta o Venta Hermoso Penthouse de dos niveles en Fraccionamiento Residencial Jardines, estrene\\n T146 M2\\n 2 filtros de vigilancia\\n Elevador\\n 3 Recámaras (la principal con baño completo y vestidor)\\n Las otras 2 con clóset \\n Cocina integral con barra\\n 2 1/2 Baños \\n Antecomedor \\n Área de lavado \\n Sala con balcón\\n Espacio para home office\\n Closet de blancos \\n 1 Estacionamiento\\n Amenidades\\n Gimnasio\\n Alberca\\n Plaza comercial\\n Mantenimiento $ 3,515.00\\nRenta  $29,000.00\\nVenta. $ 6,500.000.00\\n\\n\",\"category\":{\"code\":\"1020\",\"icon\":\"http://www.segundamano.mx/img/nga/inmuebles.png\",\"color\":\"FDE8DE\",\"label\":\"Venta inmuebles\",\"parent\":{\"code\":\"1020\",\"label\":\"Venta inmuebles\",\"parent\":{\"code\":\"1000\",\"label\":\"Inmuebles\"}}},\"list_time\":{\"label\":\"27 Mar 23 23:50 CST\",\"value\":1679982620},\"ad_details\":{\"bathrooms\":{\"single\":{\"code\":\"3\",\"label\":\"2\"}},\"contact_email\":{\"single\":{\"code\":\"eldadelaluna13@live.com.mx\",\"label\":\"eldadelaluna13@live.com.mx\"}},\"contact_phone\":{\"single\":{\"code\":\"5521298956\",\"label\":\"5521298956\"}},\"estate_type\":{\"single\":{\"code\":\"1\",\"label\":\"Departamentos\"}},\"lot_area\":{\"single\":{\"code\":\"146\",\"label\":\"146 m²\"}},\"parking_lots\":{\"single\":{\"code\":\"2\",\"label\":\"1\"}},\"rooms\":{\"single\":{\"code\":\"3\",\"label\":\"3\"}},\"size\":{\"single\":{\"code\":\"146\",\"label\":\"146 m²\"}}},\"ad_id\":\"/private/accounts/10417814/ads/75453684\",\"company_ad\":true,\"paid\":false,\"phone_hidden\":false,\"type\":{\"code\":\"s\",\"label\":\"Vendo\"},\"shop_id\":7168,\"with_shop\":true,\"price_classification\":4},\"labelmap\":{\"area\":\"Colonia\",\"bathrooms\":\"Baños\",\"body\":\"Descripción del anuncio\",\"category\":\"Categoría\",\"estate_type\":\"Tipo de inmueble\",\"images\":\"Foto principal\",\"locations\":\"Estado\",\"l ...
# var regionLabels="{\"region\":\"Ciudad de México\"}"
# var categoryLabels="{\"category\":\"Venta de Inmuebles\",\"categoryShort\":\"Venta inmuebles\"}"
# var listingPath=null
# checkWebpSupport()
# var isWebpSupported=false
# function checkWebpSupport(){const webP=new Image()
# webP.src='...'
# webP.onload=()=>{isWebpSupported=!!(webP.height>0&&webP.width>0)}}</script><script type="application/ld+json">
#   {"@context":"http://schema.org","@type":"ItemList","name":"Encuentra anuncios de todo tipo","additionalType":"SiteNavigationElement","itemListElement":[{"@type":"ListItem","position":1,"item":{"name":"Estrene magnifico PH en Residencial Jardines, Azca","url":"https://www.segundamano.mx/anuncios/ciudad-de-mexico/azcapotzalco/venta-inmuebles/estrene-magnifico-ph-en-residencial-jardines-azca-public-ads-939675809"},"name":"","url":""},{"@type":"ListItem","position":2,"item":{"name":"CASA EN VENTA EN FRACCIONAMIENTO, IZTAPALAPA, CDMX","url":"https://www.segundamano.mx/anuncios/ciudad-de-mexico/iztapalapa/venta-inmuebles/casa-en-venta-en-fraccionamiento-iztapalapa-cdmx-public-ads-938849083"},"name":"","url":""},{"@type":"ListItem","position":3,"item":{"name":"Casa en Remate Bancario Gustavo A. Madero","url":"https://www.segundamano.mx/anuncios/ciudad-de-mexico/gustavo-a-madero/venta-inmuebles/casa-en-remate-bancario-gustavo-a-madero-public-ads-938590592"},"name":"","url":""},{"@type":"ListItem","position":4,"item":{"name":"Depto Venta, Granada, Miguel Hidalgo, CDMX. ","url":"https://www.segundamano.mx/anuncios/ciudad-de-mexico/miguel-hidalgo/venta-inmuebles/depto-venta-granada-miguel-hidalgo-cdmx-public-ads-939675630"},"name":"","url":""},{"@type":"ListItem","position":5,"item":{"name":"28682 Ángel Urraza, Independencia","url":"https://www.segundamano.mx/anuncios/ciudad-de-mexico/benito-juarez/venta-inmuebles/28682-angel-urraza-independencia-public-ads-939738325"},"name":"","url":""},{"@type":"ListItem","position":6,"item":{"name":"7742 Privada del Bosque, Lomas del Chamizal","url":"https://www.segundamano.mx/anuncios/ciudad-de-mexico/cuajimalpa-de-morelos/venta-inmuebles/7742-privada-del-bosque-lomas-del-chamizal-public-ads-939738324"},"name":"","url":""},{"@type":"ListItem","position":7,"item":{"name":"25439 Carr. México-Toluca, Campestre Palo Alto","url":"https://www.segundamano.mx/anuncios/ciudad-de-mexico/cuajimalpa-de-morelos/venta-inmuebles/25439-carr-mexico-toluca-campestre-palo-alto-public-ads-939738323"},"name":"","url":""},{"@type":"ListItem","position":8,"item":{"name":"30097 Calz. de la Viga, Prado Churubusco","url":"https://www.segundamano.mx/anuncios/ciudad-de-mexico/iztapalapa/venta-inmuebles/30097-calz-de-la-viga-prado-churubusco-public-ads-939738321"},"name":"","url":""},{"@type":"ListItem","position":9,"item":{"name":"D124 - Margaritas, Lomas de Memetla","url":"https://www.segundamano.mx/anuncios/ciudad-de-mexico/cuajimalpa-de-morelos/venta-inmuebles/d124-margaritas-lomas-de-memetla-public-ads-939738320"},"name":"","url":""},{"@type":"ListItem","position":10,"item":{"name":"24783 Av. Constituyentes, Lomas Altas","url":"https://www.segundamano.mx/anuncios/ciudad-de-mexico/miguel-hidalgo/venta-inmuebles/24783-av-constituyentes-lomas-altas-public-ads-939738319"},"name":"","url":""},{"@type":"ListItem","position":11,"item":{"name":"D563 - Bordo, Valle Gómez","url":"https://www.segundamano.mx/anuncios/ciudad-de-mexico/venustiano-carranza/venta-inmuebles/d563-bordo-valle-gomez-public-ads-939738318"},"name":"","url":""},{"@type":"ListItem","position":12,"item":{"name":"2452 Plinio, Polanco III Sección","url":"https://www.segundamano.mx/anuncios/ciudad-de-mexico/miguel-hidalgo/venta-inmuebles/2452-plinio-polanco-iii-seccion-public-ads-939738316"},"name":"","url":""},{"@type":"ListItem","position":13,"item":{"name":"D981 - Obrero Mundial, Narvarte Poniente","url":"https://www.segundamano.mx/anuncios/ciudad-de-mexico/benito-juarez/venta-inmuebles/d981-obrero-mundial-narvarte-poniente-public-ads-939738314"},"name":"","url":""},{"@type":"ListItem","position":14,"item":{"name":"6331 Lago Suiza, 5 de Mayo","url":"https://www.segundamano.mx/anuncios/ciudad-de-mexico/miguel-hidalgo/venta-inmuebles/6331-lago-suiza-5-de-mayo-public-ads-939738313"},"name":"","url":""},{"@type":"ListItem","position":15,"item":{"name":"26028 Valentín Canalizó, Dinamita","url":"https://www.segundamano.mx/anuncios/ciudad-de-mexico/gustavo-a-madero/ven ...
#   </script><script charset="utf-8" defer="">(function(g,o){g[o]=g[o]||function(){(g[o]['q']=g[o]['q']||[]).push(arguments)},g[o]['t']=1*new Date})(window,'_googCsa');</script><script defer="">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.defer=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-WK47WPQ');</script><link href="/anuncios/static/css/Alerts-chunk.13af77ea.css" rel="prefetch"/><link href="/anuncios/static/css/Chips-chunk.445e6237.css" rel="prefetch"/><link href="/anuncios/static/css/Empty-chunk.c6463043.css" rel="prefetch"/><link href="/anuncios/static/css/Footer-chunk.256d188e.css" rel="prefetch"/><link href="/anuncios/static/css/FormBuilder-chunk.7aa8429a.css" rel="prefetch"/><link href="/anuncios/static/css/Login-chunk.c1930fe4.css" rel="prefetch"/><link href="/anuncios/static/css/Pagination-chunk.93f573c0.css" rel="prefetch"/><link href="/anuncios/static/css/chunk-1216a175.f7f9a840.css" rel="prefetch"/><link href="/anuncios/static/css/chunk-1fadfe4c.69c9e6f4.css" rel="prefetch"/><link href="/anuncios/static/css/chunk-32659f5a.25837a51.css" rel="prefetch"/><link href="/anuncios/static/css/chunk-6e0ebe13.9a7c1749.css" rel="prefetch"/><link href="/anuncios/static/css/chunk-77058a5e.a8caf7fc.css" rel="prefetch"/><link href="/anuncios/static/js/Alerts-chunk.7d888ff9.js" rel="prefetch"/><link href="/anuncios/static/js/Chips-chunk.bed0ac77.js" rel="prefetch"/><link href="/anuncios/static/js/Empty-chunk.60cf64d6.js" rel="prefetch"/><link href="/anuncios/static/js/Footer-chunk.4b6c22ae.js" rel="prefetch"/><link href="/anuncios/static/js/FormBuilder-chunk.c58c4da2.js" rel="prefetch"/><link href="/anuncios/static/js/Login-chunk.9c5a74f7.js" rel="prefetch"/><link href="/anuncios/static/js/Pagination-chunk.0bca545e.js" rel="prefetch"/><link href="/anuncios/static/js/chunk-1216a175.9224747e.js" rel="prefetch"/><link href="/anuncios/static/js/chunk-1fadfe4c.c787b920.js" rel="prefetch"/><link href="/anuncios/static/js/chunk-32659f5a.bd09b1c9.js" rel="prefetch"/><link href="/anuncios/static/js/chunk-6e0ebe13.d3dadebd.js" rel="prefetch"/><link href="/anuncios/static/js/chunk-77058a5e.ac858c7b.js" rel="prefetch"/></head><body><noscript><meta content="0;url='http://www.segundamano.mx/anuncios/ciudad-de-mexico/venta-inmuebles?page=1&amp;PageSpeed=noscript'" http-equiv="refresh"><style><!--table,div,span,font,p{display:none} --></style><div style="display:block">Please click <a href="http://www.segundamano.mx/anuncios/ciudad-de-mexico/venta-inmuebles?page=1&amp;PageSpeed=noscript">here</a> if you are not redirected within a few seconds.</div></meta></noscript><noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WK47WPQ" style="display:none;visibility:hidden" width="0"></iframe></noscript><div id="app"></div><div id="footer"></div><script src="/anuncios/static/js/chunk-vendors.5bebd5b4.js"></script><script src="/anuncios/static/js/app.4f830e96.js"></script><script data-pagespeed-no-defer="" type="text/javascript">(function(){function f(b){var a=window;if(a.addEventListener)a.addEventListener("load",b,!1);else if(a.attachEvent)a.attachEvent("onload",b);else{var c=a.onload;a.onload=function(){b.call(this);c&&c.call(this)}}};window.pagespeed=window.pagespeed||{};var k=window.pagespeed;function l(b,a,c,g,h){this.h=b;this.i=a;this.l=c;this.j=g;this.b=h;this.c=[];this.a=0}l.prototype.f=function(b){for(var a=0;250>a&&this.a<this.b.length;++a,++this.a)try{document.querySelector(this.b[this.a])&&this.c.push(this.b[this.a])}catch(c){}this.a<this.b.length?window.setTimeout(this.f.bind(this),0,b):b()};
# k.g=function(b,a,c,g,h){if(document.querySelector&&Function.prototype.bind){var d=new l(b,a,c,g,h);f(function(){window.setTimeout(function(){d.f(function(){for(var a="oh="+d.l+"&n="+d.j,a=a+"&cs=",b=0;b<d.c.length;++b){var c=0<b?",":"",c=c+encodeURIComponent(d.c[b]);if(131072<a.length+c.length)break;a+=c}k.criticalCssBeaconData=a;var b=d.h,c=d.i,e;if(window.XMLHttpRequest)e=new XMLHttpRequest;else if(window.ActiveXObject)try{e=new ActiveXObject("Msxml2.XMLHTTP")}catch(m){try{e=new ActiveXObject("Microsoft.XMLHTTP")}catch(n){}}e&&
# (e.open("POST",b+(-1==b.indexOf("?")?"?":"&")+"url="+encodeURIComponent(c)),e.setRequestHeader("Content-Type","application/x-www-form-urlencoded"),e.send(a))})},0)})}};k.criticalCssBeaconInit=k.g;})();
# pagespeed.selectors=["#app","*","body","html"];pagespeed.criticalCssBeaconInit('/ngx_pagespeed_beacon','http://www.segundamano.mx/anuncios/ciudad-de-mexico/venta-inmuebles?page=1','Wf6DYykYCG','O2XKxJXZlbk',pagespeed.selectors);</script></body></html>

# %%
soup.find_all("card-data grid-data")
# Out:
# []
